# %% [markdown]
# <a href="https://colab.research.google.com/github/lftrianas/MetNumUN2022II/blob/main/Lab2/lftrianas_cognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Screenshot of the 3 data courses in python uploaded to Linkedin**
# ![lftrianascognitiveclassaapplieddatadciencewithpython.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Course # 1. Python for Data Science**
# ![lftrianas_pythonfordatascience.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Course # 2. Data Analysis with Python**
# ![lftrianas_dataanalysiswhitphyton.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **Course # 3. Data Visualization with Python**
# ![lftrianas_datavisualizationwithphyton.jpg](data:image/jpeg;base64,...)
